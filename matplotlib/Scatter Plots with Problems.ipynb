# %% [markdown]
# # Scatter Plots
#
# A scatter plot (aka scatter chart, scatter graph) uses dots to represent values for two different numeric variables. The position of each dot on the horizontal and vertical axis indicates values for an individual data point. Scatter plots are used to observe relationships between variables (Cartio.com).
#
# In this part of our class, we will use surface area and Population Data for  Countries from Worldbank. As you can guess, Surface Area and Population will be our two variables.

# %%
#import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Read world bank Area Data
df_Area = pd.read_csv("data_files\Worldbank Country Area.csv",index_col=0)

df_Area.tail()
# Out:
#       Aruba  Afghanistan     Angola  Albania  Andorra   Arab World  \
# Year
# 2014  180.0     652860.0  1246700.0  27400.0    470.0  11232640.01
# 2015  180.0     652860.0  1246700.0  27400.0    470.0  11232647.01
# 2016  180.0     652860.0  1246700.0  27400.0    470.0  11232647.01
# 2017  180.0     652860.0  1246700.0  27400.0    470.0  11232647.01
# 2018  180.0     652860.0  1246700.0  27400.0    470.0  11232647.01
#
#       United Arab Emirates  Argentina  Armenia  American Samoa  ...  \
# Year                                                            ...
# 2014               71020.0  2736690.0  28470.0           200.0  ...
# 2015               71020.0  2736690.0  28470.0           200.0  ...
# 2016               71020.0  2736690.0  28470.0           200.0  ...
# 2017               71020.0  2736690.0  28470.0           200.0  ...
# 2018               71020.0  2736690.0  28470.0           200.0  ...
#
# ...

# %%
#Read world bank Population Data
df_Pop = pd.read_excel("data_files\Worldbank Population Data.xlsx",index_col=0)

df_Pop.tail()
# Out:
#        Aruba  Afghanistan    Angola  Albania  Andorra  Arab World  \
# Year
# 2015  104341     34413603  27884381  2880703    78011   396028278
# 2016  104872     35383128  28842484  2876101    77297   404024435
# 2017  105366     36296400  29816748  2873457    77001   411898967
# 2018  105845     37172386  30809762  2866376    77006   419790591
# 2019  106314     38041754  31825295  2854191    77142   427870270
#
#       United Arab Emirates  Argentina  Armenia  American Samoa  ...  \
# Year                                                            ...
# 2015               9262900   43131966  2925553           55812  ...
# 2016               9360980   43590368  2936146           55741  ...
# 2017               9487203   44044811  2944809           55620  ...
# 2018               9630959   44494502  2951776           55465  ...
# 2019               9770529   44938712  2957731           55312  ...
#
#       Virgin Islands (U.S.)   Vietnam  Vanuatu         World   Samoa   Kosovo  \
# ...

# %%
x_values = df_Area.loc[2018,:]/1000 # express in thousands of km2
y_values =  df_Pop.loc[2018,:]/1000000 #express in millions

plt.figure(dpi=150) # çözünürlük
plt.scatter(x_values, y_values)
plt.xlabel("Surface Area")
plt.ylabel("Population")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nn/py__5s8n69jgy5v1njqmdq500000gn/T/ipykernel_7129/3670730984.py in <module>
# ----> 1 x_values = df_Area.loc[2018,:]/1000 # express in thousands of km2
#       2 y_values =  df_Pop.loc[2018,:]/1000000 #express in millions
#       3
#       4 plt.figure(dpi=150)
#       5
#
# NameError: name 'df_Area' is not defined

# %%
#List of Some Euroasian countries 
Countries = ["Belgium", "Bulgaria", "Germany","Denmark","Spain","Finland","France","United Kingdom",
             "Italy","Netherlands","Norway", "Poland", "Portugal","Sweden","Turkey","Ukraine"]


#let's get 2017 surface area and population data for these countries
x_values = df_Area.loc[2018,Countries]/1000 # express in thousands of km2
y_values =  df_Pop.loc[2018,Countries]/1000000 #express in millions

#create scatter plot
plt.figure(dpi=150)
plt.scatter(x_values,y_values)

plt.title("Population - Surface Area")
plt.xlabel("Surface Area (x 1000 km2)")
plt.ylabel("Population (in millions)")
plt.show()

# %% [markdown]
# ### Using Different Marker Styles and Colors
#
# **marker styles:** https://matplotlib.org/api/markers_api.html#module-matplotlib.markers
#
# **color codes:**
# **b:** blue
# **g:** green
# **r:** red
# **c:** cyan
# **m:** magenta
# **y:** yellow
# **k:** black
# **w:** white

# %%
#create scatter plot
plt.figure(dpi=150)

#Triangular marker
plt.scatter(x_values,y_values, marker = "v", color = "#449EA1")

plt.legend(Countries)

#Red Square marker
#plt.scatter(x_values,y_values, marker='s', color='#449EA1')

#Black Mercedes marker
#plt.scatter(x_values,y_values, marker='2', color='k')

plt.show()

# %%
y_values["Turkey"]
# Out:
# 82.319724

# %%
plt.figure(dpi=150)

for country in Countries:
    plt.scatter(x_values[country], y_values[country])

#plt.xticks(rotation=90)
#plt.yticks(rotation=90)

plt.legend(Countries, loc = "center left", bbox_to_anchor= (1.02 , 0.5))

plt.title("Population - Surface Area")
plt.xlabel("Surface Area (x 1000 km2)")
plt.ylabel("Population (in millions)")
plt.show()

# %% [markdown]
# ### Figure Annotation
#
# As we can see in the above plots, countries to which each data point belong to is not shown. Which makes plots harder to read. We may want to add a small explanataion next to some or all data points in similar situations. We can achieve this by using ```pyplot.annotate()```

# %%
x_values["Belgium"]
# Out:
# 30.28

# %%
#create scatter plot
plt.figure(dpi=150)

plt.scatter(x_values,y_values)

plt.title("Population - Surface Area")
plt.xlabel("Surface Area (x 1000 km2)")
plt.ylabel("Population (in millions)")


for country in Countries:
    #message = country  +" \n(" + str(round(x_values[country],2)) + "," + str(round(y_values[country],2)) + ")"
    plt.annotate(country, (x_values[country],y_values[country]), fontsize=5) #try: fontsize=5
    
    #import pycountry  > 3 harfli ülke adları getirir.
    #conda install pycounty filan yapmak lazım.
    #country_obj = pycountry.countries.get(name=country)
    #plt.annotate(country_obj.alpha_3, (x_values[country],y_values[country]), fontsize=5)
    
    
plt.show()

# %% [markdown]
# ### Annotation offset and arrow styles
#
# **Arrow styles and other parameters:** https://matplotlib.org/3.2.2/api/text_api.html#matplotlib.text.Text

# %%
#create scatter plot
plt.figure(dpi=150)

plt.scatter(x_values,y_values)

plt.title("Population - Surface Area")
plt.xlabel("Surface Area (x 1000 km2)")
plt.ylabel("Population (in millions)")


for country in Countries:
    plt.annotate(country, (x_values[country],y_values[country]),
                 xytext=(30,30),
                 textcoords = 'offset pixels',
                 fontsize= 5,
                 arrowprops = {'arrowstyle': '-|>'})
    
    
plt.show()

# %% [markdown]
# ### Use different colors within the same data series
#
# if we supply parameter *c* (an array of integers) to scatter plot. Each integer will be mapped to a color in the current colormap. Then each data point will have the next color in line.

# %%
colors
# Out:
# array([ 91, 118, 210, 142, 107,  79,  74, 175, 200,  26,  67, 134, 161,
#        196, 229,  98])

# %%
#create random numbers for random colors 
colors = np.random.randint(0,256,len(Countries))

#colors = np.arange(0,256, 16)

colors2 = ["#449EA1" , "#9EC633", "#C633C4", "#449EA1" , "#9EC633", "#C633C4","#449EA1" , 
           "#9EC633", "#C633C4","#449EA1" , "#9EC633", "#C633C4","#449EA1" , "#9EC633", "#C633C4", "#C633C4"]

#create scatter plot
plt.figure(dpi=150)

plt.scatter(x_values,y_values, c = colors)

plt.title("Population - Surface Area")
plt.xlabel("Surface Area (x 1000 km2)")
plt.ylabel("Population (in millions)")


for country in Countries:
    plt.annotate(country, (x_values[country],y_values[country]),
                 xytext=(5,5),
                 textcoords = 'offset pixels',
                 fontsize= 5)
    
    
plt.show()

# %% [markdown]
# ### Use different colormaps
#
# This applies to all kinds of figures we can create with Matplotlib. We can change to colormap of the figure by changing *cmap* parameter.
#
# **full list of colormaps:** https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

# %%
#create random numbers for random colors 
np.random.seed(10)
colors = np.random.randint(0,256,len(Countries))

#create scatter plot
plt.figure(dpi=150)

plt.scatter(x_values,y_values,c = colors,cmap= 'Spectral')
#plt.scatter(x_values,y_values,c = np.arange(0,16),cmap= 'tab20')
#plt.scatter(x_values,y_values,c = colors,cmap= 'Greens')


plt.title("Population - Surface Area")
plt.xlabel("Surface Area (x 1000 km2)")
plt.ylabel("Population (in millions)")


for country in Countries:
    plt.annotate(country, (x_values[country],y_values[country]),
                 xytext=(5,5),
                 textcoords = 'offset pixels',
                 fontsize= 5)
    
    
plt.show()

# %% [markdown]
# ### Adding a third dimension to a Scatter Plot (i.e. Create a Bubble Plot)
#
# We can create a bubble plot by supplying individual marker sizes to each data point. We can achieve this by setting parameter *s* for scatter plot equal to an array containing the size of individual data points.
#
# Let's make the size of each data point proportional to the corresponding country's GDP. Hence the third dimension in our figure will be the GDP of the country.

# %%
#Read world bank GDP Data
df_GDP = pd.read_excel("data_files\Worldbank GDP Data.xlsx",index_col=0)

#Fill missing values with 0 
#df_GDP = df_GDP.fillna(0)

#express in billions of dollars
df_GDP = df_GDP /1000000000

df_GDP.tail()
# Out:
#          Aruba  Afghanistan      Angola    Albania   Andorra   Arab World  \
# Year
# 2015  2.919553    19.907111  116.193649  11.386846  2.789870  2529.694234
# 2016  2.965922    19.362642  101.123851  11.861201  2.896679  2463.433552
# 2017  3.056425    20.191760  122.123822  13.019693  3.000181  2513.494435
# 2018       NaN    19.484385  101.353231  15.147021  3.218316  2772.024699
# 2019       NaN    19.101354   94.635416  15.278077  3.154058  2815.410447
#
#       United Arab Emirates   Argentina    Armenia  American Samoa  ...  \
# Year                                                               ...
# 2015            358.135058  594.749285  10.553338           0.661  ...
# 2016            357.045065  557.531376  10.546135           0.652  ...
# 2017            385.605507  642.695865  11.527459           0.602  ...
# 2018            422.215044  519.871520  12.457942           0.636  ...
# 2019            421.142268  449.663447  13.672802             NaN  ...
#
# ...

# %%
#get 2018 GDP for relevant countries

gdps= df_GDP.loc[2018,Countries]

gdps
# Out:
# Belgium            542.685915
# Bulgaria            66.200848
# Germany           3949.548834
# Denmark            355.675329
# Spain             1419.735245
# Finland            275.893681
# France            2787.863959
# United Kingdom    2860.667728
# Italy             2085.764301
# Netherlands        914.104848
# Norway             434.166615
# Poland             587.114101
# Portugal           241.274629
# Sweden             555.455371
# Turkey             771.350331
# Ukraine            130.901858
# Name: 2018, dtype: float64

# %%
#create random numbers for random colors 
np.random.seed(10)
colors = np.arange(0,16)

#create scatter plot
plt.figure(dpi=150)

#add size information here
#add alpha to make circles transparent
plt.scatter(x_values,y_values,c = colors, s=gdps, cmap= 'tab20', alpha =0.4)



plt.title("Population - Surface Area")
plt.xlabel("Surface Area (x 1000 $km^{2}$)")
plt.ylabel("Population (in millions)")


for country in Countries:
    plt.annotate(country, (x_values[country],y_values[country]),
                 horizontalalignment = "center",
                 verticalalignment = "center",
                 fontsize= 5)
    

#change limits to make sure all bubbles fit in the graph
plt.xlim(-50,900)
plt.ylim(-5,100)

#plt.yticks([0 ,5, 10 ,15, 20, 40, 60, 80, 85,90,95,100])
    
    
plt.show()

# %% [markdown]
# After adding the third dimension, arrows are not working well. Let's remove the arrows and center the country name:

# %%
np.random.seed(10)
colors = np.random.randint(0,100,len(Countries))

#create scatter plot
plt.figure(dpi=150)

        
#add size information here
#add alpha to make circles transparent
plt.scatter(x_values[gdps > 500],y_values[gdps > 500],c = colors[gdps > 500], s=gdps[gdps > 500], marker = "o", cmap= 'Spectral', alpha = 0.5)
plt.scatter(x_values[gdps < 500],y_values[gdps < 500],c = colors[gdps < 500], s=gdps[gdps < 500], marker = "s", cmap= 'Spectral', alpha = 0.5)



plt.title("Population - Surface Area")
plt.xlabel("Surface Area (x 1000 $km^{2}$)")
plt.ylabel("Population (in millions)")


for country in Countries:
    plt.annotate(country, (x_values[country],y_values[country]),
                 xytext=(0,0),
                 textcoords = 'offset pixels',
                 fontsize= 5,
                 verticalalignment = "center",
                 horizontalalignment = "center")
    

#change limits to make sure all bubbles fit in the graph
plt.xlim(-50,900)
plt.ylim(-5,100)
    
    
plt.show()

# %%
gdps > 500
# Out:
# Belgium            True
# Bulgaria          False
# Germany            True
# Denmark           False
# Spain              True
# Finland           False
# France             True
# United Kingdom     True
# Italy              True
# Netherlands        True
# Norway            False
# Poland             True
# Portugal          False
# Sweden             True
# Turkey             True
# Ukraine           False
# Name: 2018, dtype: bool

# %% [markdown]
# # Practice Question
#
# Pay attention to the dataset given below:

# %%
df_PerCapita = pd.read_excel("data_files\gdpPerCapita.xlsx")
df_PerCapita
# Out:
#                 country continent  year  lifeExp       pop     gdpPercap  \
# 0           Afghanistan      Asia  2007   43.828  31889923    974.580338
# 1               Albania    Europe  2007   76.423   3600523   5937.029526
# 2               Algeria    Africa  2007   72.301  33333216   6223.367465
# 3                Angola    Africa  2007   42.731  12420476   4797.231267
# 4             Argentina  Americas  2007   75.320  40301927  12779.379640
# ..                  ...       ...   ...      ...       ...           ...
# 137             Vietnam      Asia  2007   74.249  85262356   2441.576404
# 138  West Bank and Gaza      Asia  2007   73.422   4018332   3025.349798
# 139         Yemen, Rep.      Asia  2007   62.698  22211743   2280.769906
# 140              Zambia    Africa  2007   42.384  11746035   1271.211593
# 141            Zimbabwe    Africa  2007   43.487  12311143    469.709298
#
#     iso_alpha  iso_num
# 0         AFG        4
# 1         ALB        8
# ...

# %% [markdown]
# Recreate the figure below for 30 countries randomly selected from the dataset above. Use log scale for gdp per capita.
# ![Practice 5](images\practice5.png)

# %%
numCountries = 30

plt.figure(dpi=150)

df = df_PerCapita.sample(numCountries, random_state=15).reset_index(drop=True)
df.set_index("country", inplace=True)
np.random.seed(10)
colors = np.random.randint(0,100,numCountries)
#TODO: Implement here

# %%
df
# Out:
#                  continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# country
# Austria             Europe  2007   79.829     8199783  36126.492700       AUT
# Namibia             Africa  2007   52.906     2055080   4811.060429       NAM
# Norway              Europe  2007   80.196     4627926  49357.190170       NOR
# Kenya               Africa  2007   54.110    35610177   1463.249282       KEN
# Mozambique          Africa  2007   42.082    19951656    823.685621       MOZ
# New Zealand        Oceania  2007   80.204     4115771  25185.009110       NZL
# Mexico            Americas  2007   76.195   108700891  11977.574960       MEX
# Saudi Arabia          Asia  2007   72.777    27601038  21654.831940       SAU
# South Africa        Africa  2007   49.339    43997828   9269.657808       ZAF
# Peru              Americas  2007   71.421    28674757   7408.905561       PER
# Ghana               Africa  2007   60.022    22873338   1327.608910       GHA
# ...
